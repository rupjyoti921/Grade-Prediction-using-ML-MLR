# %% [markdown]
# # Students Grade Prediction using Machine Learning

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Importing all Libraries

# %%
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Importing Data Set

# %%
# importing csv file 
df=pd.read_csv("C:\\Users\\user_name\\Desktop\\updated\DataSet.csv")

# %%
# Showing Data set
df
# Out:
#       Study_hour  Assignment  Attendance  Quiz_one  Quiz_two  Midsem  Endsem  \
# 0              0           1           1         1         1       5       8
# 1              1           2           3         1         2       9      12
# 2              4           3           4         4         3      23      25
# 3              5           5           5         5         4      23      36
# 4              0           1           2         1         2       1       8
# 5              4           5           4         4         4      23      30
# 6              0           1           2         2         1       4       5
# 7              6           5           5         5         5      26      42
# 8              2           2           3         2         2      14      15
# 9              4           5           4         3         3      22      32
# 10             6           5           5         5         5      27      43
# 11             1           2           3         1         2      10       9
# 12             1           1           2         2         2      10      12
# 13             1           1           3         2         2       8       9
# 14             6           5           5         5         5      29      39
# 15             5           4           5         5         5      25      40
# 16             7           5           5         5         5      29      44
# 17             3           4           4         3         3      19      18
# 18             1           2           2         2         2      10       7
# 19             0           1           1         2         2       5       7
# 20             3           4           4         4         4      15      20
# 21             7           5           5         5         5      28      47
# 22             5           4           5         5         5      26      30
# 23             6           5           5         5         5      25      45
# 24             3           4           3         4         4      19      18
# 25             3           4           3         3         2      18      16
# 26             2           3           2         3         2      12      15
# 27             5           5           4         4         5      24      41
# 28             4           5           5         3         4      23      25
# 29             3           4           4         4         3      17      17
# ...          ...         ...         ...       ...       ...     ...     ...
# 3970           2           3           3         1         1      11       8
# 3971           0           2           2         2         2       4       2
# 3972           7           5           5         5         5      27      42
# 3973           1           2           2         2         2       7      11
# 3974           0           2           1         1         1       2       8
# 3975           4           3           5         3         3      21      25
# 3976           4           5           5         3         3      23      31
# 3977           7           5           5         5         5      30      48
# 3978           6           5           5         5         5      25      42
# 3979           7           5           5         5         5      29      42
# 3980           6           5           5         5         5      26      39
# 3981           0           2           1         1         2       5       7
# 3982           4           3           4         4         3      23      32
# 3983           6           5           5         5         5      27      40
# 3984           6           5           5         5         5      25      44
# 3985           0           2           1         2         2       2       4
# 3986           1           2           1         2         2      10      13
# 3987           7           5           5         5         5      27      43
# 3988           6           5           5         5         5      28      41
# 3989           0           2           1         1         1       4       3
# 3990           6           5           5         5         5      28      41
# 3991           3           3           3         3         4      19      21
# 3992           6           5           5         5         5      29      45
# 3993           0           1           2         2         2       3       7
# 3994           1           2           3         2         2      10      13
# 3995           6           5           5         5         5      25      43
# 3996           7           5           5         5         5      27      48
# 3997           1           2           1         1         2      10      15
# 3998           6           5           5         5         5      29      46
# 3999           3           4           4         2         2      19      15
#
#      Pass_Fail
# 0         fail
# 1         fail
# 2         pass
# 3         pass
# 4         fail
# 5         pass
# 6         fail
# 7         pass
# 8         pass
# 9         pass
# 10        pass
# 11        fail
# 12        fail
# 13        fail
# 14        pass
# 15        pass
# 16        pass
# 17        pass
# 18        fail
# 19        fail
# 20        pass
# 21        pass
# 22        pass
# 23        pass
# 24        pass
# 25        pass
# 26        pass
# 27        pass
# 28        pass
# 29        pass
# ...        ...
# 3970      fail
# 3971      fail
# 3972      pass
# 3973      fail
# 3974      fail
# 3975      pass
# 3976      pass
# 3977      pass
# 3978      pass
# 3979      pass
# 3980      pass
# 3981      fail
# 3982      pass
# 3983      pass
# 3984      pass
# 3985      fail
# 3986      fail
# 3987      pass
# 3988      pass
# 3989      fail
# 3990      pass
# 3991      pass
# 3992      pass
# 3993      fail
# 3994      fail
# 3995      pass
# 3996      pass
# 3997      fail
# 3998      pass
# 3999      pass
#
# [4000 rows x 8 columns]

# %% [markdown]
# # Visual analyzation of the Dataset

# %%
#showing the corelation of each column with each other.
corr_matrix = df.corr()
sns.heatmap(corr_matrix, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # 1. Multiple Linear Regression Model

# %% [markdown]
# # ......................................................................

# %% [markdown]
# # Assigning Independent variable X and Dependent variable y

# %%
# Let's separate Independent variable X and Dependent variable y

X= df[['Study_hour', 'Assignment', 'Attendance', 'Quiz_one', 'Quiz_two', 'Midsem']]
y = df['Endsem']

# %% [markdown]
# # Spliting Data Set

# %%
# split data for training and testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.34)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.34)

# Calculate the sizes of each segment for the pie chart
sizes = [len(X_train), len(X_test), len(y_train), len(y_test)]

# Define the colors for each segment for the pie chart
colors = ['lightblue', 'lightgreen', 'pink', 'green']

# Create the pie chart on the first subplot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.pie(sizes, labels=['X_train', 'X_test', 'y_train', 'y_test'], colors=colors, autopct='%1.1f%%', startangle=90)
ax1.set_title('Data Split')

# Calculate the sizes of each segment for the bar chart
train_size = len(X_train)
test_size = len(X_test)
sizes = [train_size, test_size]
labels = ['Training set', 'Testing set']
colors = ['blue', 'green']

# Create the bar chart on the second subplot
bars = ax2.bar(labels, sizes, color=colors)
ax2.set_title('Proportions of Training and Testing Sets')
ax2.set_xlabel('Dataset')
ax2.set_ylabel('Number of samples')

# Add text labels for each bar
for bar in bars:
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height, '%d' % int(height), ha='center', va='bottom')

# Adjust the layout
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Training the model

regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# # Prediction

# %%
# prediction by giving the X_test data to the model and 
# geting prediction data in y_pred variable

y_pred=regression.predict(X_test)

# %% [markdown]
# # Comparing Actual End sem marks and Predicted marks

# %%
df2 = pd.DataFrame({'Actual_Endsem': y_test, 'Predicted_Endsem': y_pred})
df2.head(20)
# Out:
#       Actual_Endsem  Predicted_Endsem
# 1207             15         21.281811
# 2871             24         28.847602
# 2672             12          8.841271
# 2999             22         21.173964
# 1173             16         20.680011
# 2639             23         21.649750
# 1374             27         28.171412
# 956               9         14.853966
# 535              18         15.949441
# 73               40         35.162021
# 2839             44         41.175884
# 909              42         41.068036
# 2591             22         20.998253
# 446              45         41.068036
# 3632             35         33.914302
# 2828             46         46.264402
# 2856             25         28.973616
# 3757             49         46.372250
# 531              41         40.852340
# 1468             41         41.068036

# %%
# Graph showing comparison between actual_total and predicted_total.
plt = df2.head(50)
plt.plot(kind='bar',figsize=(15,5), color=["red", "green"], title= "Comaparison between Actual_Total and Predicted_Total Endsem Marks")

# %% [markdown]
# # Let's calculate Total Actual and Predicted Marks

# %%
# calculate total of actual marks (X_test+y_test)

temp_sum=0
total=0
total_actual_marks=[]

len_test_data=len(y_test)

for i in range(0,len_test_data):
        for j in range(1,6):
                temp_sum+=X_test.iat[i,j]
        
        total=temp_sum +y_test.iat[i]
        total_actual_marks.append(total)
        temp_sum=0
        total=0

#printing total actual marks (Assignment+Attendance+Quiz_one+Quiz_two+Midsem+Endsem) 

total_actual_marks
# Out:
# [43,
#  60,
#  24,
#  51,
#  43,
#  53,
#  65,
#  30,
#  38,
#  85,
#  90,
#  89,
#  51,
#  92,
#  77,
#  95,
#  61,
#  97,
#  90,
#  88,
#  74,
#  57,
#  95,
#  92,
#  50,
#  14,
#  92,
#  76,
#  30,
#  61,
#  36,
#  63,
#  64,
#  17,
#  24,
#  27,
#  34,
#  35,
#  62,
#  84,
#  23,
#  25,
#  25,
#  50,
#  85,
#  80,
#  28,
#  17,
#  82,
#  49,
#  80,
#  92,
#  72,
#  49,
#  73,
#  65,
#  50,
#  72,
#  62,
#  80,
#  91,
#  16,
#  16,
#  82,
#  83,
#  76,
#  50,
#  30,
#  65,
#  22,
#  30,
#  40,
#  93,
#  14,
#  72,
#  99,
#  17,
#  78,
#  35,
#  69,
#  16,
#  17,
#  33,
#  87,
#  93,
#  97,
#  19,
#  76,
#  93,
#  98,
#  23,
#  14,
#  94,
#  31,
#  93,
#  49,
#  92,
#  68,
#  23,
#  77,
#  93,
#  41,
#  51,
#  33,
#  97,
#  94,
#  97,
#  72,
#  68,
#  94,
#  90,
#  97,
#  10,
#  54,
#  69,
#  45,
#  20,
#  33,
#  41,
#  88,
#  63,
#  86,
#  71,
#  54,
#  21,
#  86,
#  19,
#  93,
#  48,
#  71,
#  90,
#  31,
#  26,
#  96,
#  93,
#  21,
#  14,
#  74,
#  93,
#  78,
#  54,
#  53,
#  48,
#  10,
#  97,
#  97,
#  32,
#  92,
#  83,
#  93,
#  87,
#  34,
#  40,
#  96,
#  98,
#  81,
#  40,
#  39,
#  16,
#  72,
#  95,
#  81,
#  52,
#  11,
#  97,
#  47,
#  33,
#  30,
#  72,
#  73,
#  40,
#  85,
#  26,
#  49,
#  86,
#  90,
#  82,
#  54,
#  94,
#  87,
#  83,
#  17,
#  32,
#  98,
#  40,
#  86,
#  90,
#  93,
#  90,
#  75,
#  89,
#  55,
#  65,
#  52,
#  16,
#  95,
#  9,
#  23,
#  43,
#  33,
#  17,
#  89,
#  51,
#  81,
#  96,
#  21,
#  96,
#  81,
#  93,
#  29,
#  75,
#  42,
#  36,
#  91,
#  54,
#  52,
#  93,
#  65,
#  46,
#  85,
#  85,
#  98,
#  67,
#  74,
#  54,
#  80,
#  72,
#  47,
#  88,
#  89,
#  47,
#  19,
#  96,
#  19,
#  83,
#  92,
#  14,
#  22,
#  21,
#  37,
#  87,
#  92,
#  36,
#  74,
#  94,
#  12,
#  31,
#  27,
#  96,
#  56,
#  84,
#  18,
#  73,
#  12,
#  64,
#  61,
#  38,
#  43,
#  19,
#  15,
#  17,
#  14,
#  57,
#  49,
#  36,
#  31,
#  90,
#  68,
#  27,
#  82,
#  32,
#  13,
#  47,
#  71,
#  10,
#  38,
#  98,
#  23,
#  15,
#  27,
#  73,
#  95,
#  19,
#  23,
#  84,
#  98,
#  97,
#  19,
#  17,
#  11,
#  47,
#  82,
#  15,
#  91,
#  13,
#  92,
#  99,
#  98,
#  30,
#  16,
#  74,
#  94,
#  99,
#  20,
#  37,
#  47,
#  71,
#  89,
#  30,
#  35,
#  16,
#  72,
#  76,
#  68,
#  81,
#  100,
#  91,
#  81,
#  34,
#  17,
#  30,
#  100,
#  40,
#  22,
#  29,
#  99,
#  27,
#  85,
#  92,
#  62,
#  15,
#  47,
#  65,
#  98,
#  65,
#  60,
#  11,
#  46,
#  32,
#  80,
#  74,
#  74,
#  78,
#  50,
#  79,
#  69,
#  88,
#  14,
#  95,
#  10,
#  94,
#  100,
#  24,
#  50,
#  67,
#  26,
#  19,
#  47,
#  45,
#  88,
#  92,
#  38,
#  19,
#  66,
#  86,
#  16,
#  45,
#  14,
#  18,
#  31,
#  78,
#  31,
#  52,
#  29,
#  17,
#  81,
#  97,
#  30,
#  89,
#  39,
#  27,
#  100,
#  13,
#  88,
#  99,
#  29,
#  93,
#  53,
#  72,
#  46,
#  89,
#  17,
#  23,
#  97,
#  14,
#  15,
#  26,
#  73,
#  89,
#  38,
#  95,
#  16,
#  64,
#  68,
#  94,
#  34,
#  99,
#  66,
#  95,
#  35,
#  82,
#  10,
#  90,
#  13,
#  91,
#  54,
#  16,
#  31,
#  79,
#  92,
#  53,
#  90,
#  95,
#  62,
#  80,
#  76,
#  35,
#  91,
#  8,
#  78,
#  31,
#  97,
#  17,
#  29,
#  31,
#  97,
#  84,
#  18,
#  49,
#  28,
#  84,
#  44,
#  92,
#  76,
#  71,
#  85,
#  25,
#  27,
#  24,
#  52,
#  87,
#  15,
#  77,
#  12,
#  33,
#  84,
#  93,
#  47,
#  44,
#  29,
#  82,
#  10,
#  87,
#  18,
#  49,
#  93,
#  99,
#  14,
#  51,
#  86,
#  85,
#  48,
#  84,
#  46,
#  86,
#  39,
#  97,
#  81,
#  68,
#  36,
#  21,
#  94,
#  67,
#  63,
#  29,
#  37,
#  70,
#  29,
#  8,
#  79,
#  12,
#  18,
#  72,
#  89,
#  88,
#  80,
#  13,
#  50,
#  87,
#  86,
#  51,
#  29,
#  42,
#  88,
#  30,
#  100,
#  24,
#  38,
#  85,
#  88,
#  89,
#  14,
#  76,
#  16,
#  37,
#  14,
#  90,
#  78,
#  94,
#  54,
#  45,
#  70,
#  91,
#  64,
#  87,
#  73,
#  83,
#  95,
#  79,
#  96,
#  84,
#  15,
#  70,
#  16,
#  60,
#  94,
#  12,
#  13,
#  51,
#  33,
#  84,
#  9,
#  36,
#  94,
#  31,
#  53,
#  86,
#  20,
#  26,
#  90,
#  68,
#  48,
#  18,
#  75,
#  87,
#  27,
#  16,
#  85,
#  87,
#  72,
#  93,
#  66,
#  38,
#  98,
#  87,
#  33,
#  84,
#  49,
#  95,
#  12,
#  28,
#  70,
#  34,
#  54,
#  92,
#  80,
#  48,
#  23,
#  90,
#  60,
#  90,
#  33,
#  95,
#  61,
#  92,
#  55,
#  90,
#  23,
#  15,
#  11,
#  85,
#  71,
#  51,
#  19,
#  88,
#  37,
#  72,
#  10,
#  29,
#  76,
#  78,
#  72,
#  58,
#  71,
#  11,
#  48,
#  93,
#  29,
#  36,
#  65,
#  21,
#  26,
#  95,
#  80,
#  86,
#  96,
#  47,
#  98,
#  43,
#  64,
#  91,
#  68,
#  26,
#  90,
#  27,
#  98,
#  89,
#  89,
#  21,
#  53,
#  85,
#  49,
#  49,
#  94,
#  66,
#  94,
#  33,
#  13,
#  95,
#  53,
#  71,
#  31,
#  99,
#  13,
#  97,
#  51,
#  35,
#  93,
#  75,
#  12,
#  32,
#  83,
#  55,
#  72,
#  87,
#  41,
#  26,
#  46,
#  43,
#  66,
#  91,
#  100,
#  21,
#  10,
#  31,
#  52,
#  62,
#  13,
#  86,
#  75,
#  81,
#  27,
#  88,
#  63,
#  23,
#  88,
#  17,
#  70,
#  67,
#  87,
#  91,
#  87,
#  76,
#  48,
#  38,
#  89,
#  25,
#  27,
#  84,
#  41,
#  81,
#  27,
#  48,
#  89,
#  17,
#  63,
#  22,
#  91,
#  93,
#  24,
#  77,
#  28,
#  28,
#  47,
#  52,
#  48,
#  60,
#  13,
#  58,
#  16,
#  94,
#  61,
#  80,
#  92,
#  37,
#  70,
#  82,
#  88,
#  34,
#  54,
#  24,
#  14,
#  91,
#  15,
#  21,
#  24,
#  91,
#  52,
#  45,
#  27,
#  62,
#  51,
#  10,
#  32,
#  14,
#  23,
#  47,
#  13,
#  24,
#  87,
#  38,
#  25,
#  97,
#  77,
#  91,
#  93,
#  95,
#  94,
#  81,
#  19,
#  84,
#  64,
#  13,
#  91,
#  91,
#  74,
#  86,
#  97,
#  69,
#  76,
#  94,
#  78,
#  68,
#  79,
#  14,
#  38,
#  50,
#  15,
#  85,
#  100,
#  26,
#  88,
#  85,
#  88,
#  23,
#  92,
#  99,
#  16,
#  25,
#  97,
#  23,
#  88,
#  76,
#  77,
#  49,
#  16,
#  31,
#  18,
#  28,
#  85,
#  49,
#  29,
#  29,
#  36,
#  80,
#  92,
#  85,
#  33,
#  17,
#  69,
#  34,
#  81,
#  90,
#  32,
#  14,
#  92,
#  80,
#  42,
#  67,
#  75,
#  50,
#  61,
#  65,
#  62,
#  11,
#  93,
#  78,
#  99,
#  50,
#  72,
#  38,
#  96,
#  90,
#  23,
#  31,
#  52,
#  91,
#  48,
#  92,
#  17,
#  35,
#  88,
#  37,
#  86,
#  82,
#  28,
#  30,
#  26,
#  92,
#  29,
#  14,
#  10,
#  13,
#  69,
#  95,
#  91,
#  36,
#  33,
#  63,
#  34,
#  16,
#  87,
#  42,
#  12,
#  14,
#  91,
#  83,
#  33,
#  23,
#  39,
#  11,
#  96,
#  34,
#  59,
#  90,
#  79,
#  36,
#  44,
#  47,
#  97,
#  32,
#  31,
#  43,
#  45,
#  37,
#  90,
#  95,
#  31,
#  26,
#  92,
#  85,
#  14,
#  46,
#  93,
#  68,
#  26,
#  95,
#  76,
#  16,
#  92,
#  85,
#  95,
#  88,
#  16,
#  27,
#  32,
#  71,
#  16,
#  91,
#  36,
#  81,
#  63,
#  95,
#  35,
#  49,
#  93,
#  15,
#  26,
#  86,
#  11,
#  76,
#  18,
#  72,
#  94,
#  51,
#  38,
#  35,
#  66,
#  89,
#  89,
#  25,
#  25,
#  52,
#  96,
#  12,
#  54,
#  43,
#  48,
#  77,
#  85,
#  92,
#  92,
#  86,
#  54,
#  87,
#  21,
#  14,
#  93,
#  95,
#  92,
#  95,
#  84,
#  21,
#  73,
#  34,
#  61,
#  50,
#  65,
#  56,
#  66,
#  96,
#  26,
#  30,
#  32,
#  37,
#  32,
#  79,
#  56,
#  93,
#  49,
#  93,
#  47,
#  65,
#  27,
#  94,
#  28,
#  37,
#  76,
#  87,
#  33,
#  73,
#  31,
#  23,
#  85,
#  77,
#  54,
#  14,
#  48,
#  22,
#  31,
#  73,
#  64,
#  75,
#  95,
#  54,
#  90,
#  99,
#  84,
#  49,
#  90,
#  52,
#  40,
#  89,
#  65,
#  57,
#  61,
#  16,
#  39,
#  21,
#  17,
#  ...]

# %%
# calculate total of predicted marks (X_test+y_pred)

temp_sum=0
total=0
total_predicted_marks=[]

len_pred_data=len(y_pred)

for i in range(0,len_pred_data):
        for j in range(1,6):
                temp_sum+=X_test.iat[i,j]
        
        total=temp_sum +y_pred[i]
        total_predicted_marks.append(total)
        temp_sum=0
        total=0
        
#printing total predicted marks (Assignment+Attendance+Quiz_one+Quiz_two+Midsem+ Predicted_Endsem) 

total_predicted_marks
# Out:
# [49.28181135207244,
#  64.84760201233604,
#  20.841271140460883,
#  50.17396361404419,
#  47.68001128362354,
#  51.64974995885723,
#  66.1714116287875,
#  35.85396571108092,
#  35.94944144151904,
#  80.16202133489787,
#  87.17588354096985,
#  88.06803580294161,
#  49.99825258573825,
#  88.06803580294161,
#  75.91430247373144,
#  95.26440246450821,
#  64.97361573597189,
#  94.37225020253646,
#  89.8523403268851,
#  88.06803580294161,
#  76.72621943783538,
#  53.71203466873348,
#  93.4800979405647,
#  94.37225020253646,
#  56.175449005956395,
#  14.228538561735565,
#  88.06803580294161,
#  74.84643918345375,
#  35.8013938581242,
#  66.09117633091968,
#  37.585698382067704,
#  64.97361573597189,
#  67.87548085486318,
#  11.867393382139447,
#  24.203631166844225,
#  24.459577493017978,
#  36.212181194881474,
#  32.541302989367665,
#  64.34420322736256,
#  87.17588354096985,
#  24.153933862174135,
#  22.59503767120666,
#  27.76544678754256,
#  45.769693036044195,
#  78.33481293347293,
#  78.91165358912556,
#  24.379342195150166,
#  12.496805890748773,
#  88.96018806491335,
#  93.4800979405647,
#  36.51104166460134,
#  25.928570410642347,
#  89.8523403268851,
#  86.28373127899809,
#  13.64490447889428,
#  51.927730144789976,
#  88.06803580294161,
#  65.22956206214565,
#  19.06376004370605,
#  96.15655472647995,
#  79.26986907292611,
#  15.932607787811257,
#  96.15655472647995,
#  87.17588354096985,
#  89.8523403268851,
#  88.06803580294161,
#  14.586754045536122,
#  24.151059313887515,
#  34.37530481798126,
#  65.27925936681574,
#  11.787158084271635,
#  89.8523403268851,
#  36.89129100816089,
#  77.20758436304986,
#  65.05385103383969,
#  93.4800979405647,
#  37.05176160389651,
#  47.60656941294441,
#  96.15655472647995,
#  10.79273666467308,
#  22.449864636098447,
#  88.06803580294161,
#  12.672516919054715,
#  80.95190443924281,
#  16.82476004978301,
#  65.69005696963771,
#  89.8523403268851,
#  50.090853767889755,
#  37.505463084199896,
#  37.536001077397614,
#  65.27925936681574,
#  86.28373127899809,
#  86.28373127899809,
#  22.36962933823063,
#  21.835692560059435,
#  50.810169549842186,
#  96.15655472647995,
#  10.258799886501887,
#  53.76173197340357,
#  48.541625552397576,
#  49.514013112237144,
#  80.11232403022777,
#  86.28373127899809,
#  95.26440246450821,
#  89.8523403268851,
#  86.28373127899809,
#  51.702321811813945,
#  88.96018806491335,
#  22.727844822031187,
#  11.962869112577577,
#  88.96018806491335,
#  94.37225020253646,
#  88.96018806491335,
#  95.26440246450821,
#  86.28373127899809,
#  24.196837739655553,
#  78.32801950628428,
#  36.92182900135861,
#  65.73975427430778,
#  49.07556233056877,
#  64.16169877186795,
#  54.474254328167326,
#  66.52963737865274,
#  96.15655472647995,
#  22.727844822031187,
#  25.805431235293113,
#  34.19959378967531,
#  38.808402682928914,
#  37.104333456853226,
#  80.87166914137501,
#  55.999737977650454,
#  88.06803580294161,
#  53.65946281577676,
#  88.06803580294161,
#  48.213948061794746,
#  65.73975427430778,
#  26.740487374746287,
#  89.8523403268851,
#  23.35438278235389,
#  37.74053939265122,
#  78.33481293347293,
#  89.8523403268851,
#  33.615959706834026,
#  67.65007252188714,
#  39.1598350056055,
#  23.258907051915763,
#  79.04446073995007,
#  78.33481293347293,
#  52.77018510209163,
#  12.802449521592617,
#  45.90250018686872,
#  25.043211575859267,
#  24.993514271189174,
#  67.5240587982513,
#  64.98040916316056,
#  80.11232403022777,
#  96.15655472647995,
#  50.3785019292978,
#  88.06803580294161,
#  96.15655472647995,
#  79.04446073995007,
#  54.19339959394796,
#  93.4800979405647,
#  49.07556233056877,
#  38.49988450379845,
#  87.17588354096985,
#  67.01386658608915,
#  55.46580119947926,
#  65.1035483385098,
#  15.173262676664027,
#  37.585698382067704,
#  23.434618080221703,
#  16.108318816117198,
#  ...]

# %% [markdown]
# # Comparing Total Actual marks and Total Predicted Marks

# %%
# Comparing total Actual marks and Total Predicted Marks

df3 = pd.DataFrame({'Actual_Total':total_actual_marks, 'Predicted_Total':total_predicted_marks})
df3.head(20)
# Out:
#     Actual_Total  Predicted_Total
# 0             43        49.281811
# 1             60        64.847602
# 2             24        20.841271
# 3             51        50.173964
# 4             43        47.680011
# 5             53        51.649750
# 6             65        66.171412
# 7             30        35.853966
# 8             38        35.949441
# 9             85        80.162021
# 10            90        87.175884
# 11            89        88.068036
# 12            51        49.998253
# 13            92        88.068036
# 14            77        75.914302
# 15            95        95.264402
# 16            61        64.973616
# 17            97        94.372250
# 18            90        89.852340
# 19            88        88.068036

# %%
import matplotlib.pyplot as plt  

df3_head = df3.head(200)
plt.figure(figsize=(20,5)) # add figsize parameter here
plt.plot(df3_head.index, df3_head['Actual_Total'], label='Actual_Total')
plt.plot(df3_head.index, df3_head['Predicted_Total'], label='Predicted_Total')

plt.title('Actual vs Predicted Total Marks')
plt.xlabel('Student Index')
plt.ylabel('Total Marks')

plt.legend()
plt.show()

# %% [markdown]
# # Computing Actual and Predicted Grade

# %%
# Calculating Actual Grade

len_actual_marks=len(total_actual_marks)
actual_grade=[]

for i in range(0,len_actual_marks):
    if total_actual_marks[i]>85:
        actual_grade.append("S")
    elif total_actual_marks[i]>75:
        actual_grade.append("A")
    elif total_actual_marks[i]>65:
        actual_grade.append("B")
    elif total_actual_marks[i]>55:
        actual_grade.append("C")
    elif total_actual_marks[i]>45:
        actual_grade.append("D")
    elif total_actual_marks[i]>34:
        actual_grade.append("E")
    else:
        actual_grade.append("F")

# %%
# Calculating Predicted Grade

len_predicted_marks=len(total_predicted_marks)
predicted_grade=[]

for i in range(0,len_predicted_marks):
    if total_predicted_marks[i]>85:
        predicted_grade.append("S")
    elif total_predicted_marks[i]>75:
        predicted_grade.append("A")
    elif total_predicted_marks[i]>65:
        predicted_grade.append("B")
    elif total_predicted_marks[i]>55:
        predicted_grade.append("C")
    elif total_predicted_marks[i]>45:
        predicted_grade.append("D")
    elif total_predicted_marks[i]>34:
        predicted_grade.append("E")
    else:
        predicted_grade.append("F")

# %% [markdown]
# # Comparing Actual and Predicted Grade

# %%
df4 = pd.DataFrame({'Actual_Grade':actual_grade, 'Predicted_Grade':predicted_grade})
df4.head(20)
# Out:
#    Actual_Grade Predicted_Grade
# 0             E               D
# 1             C               C
# 2             F               F
# 3             D               D
# 4             E               D
# 5             D               D
# 6             C               B
# 7             F               E
# 8             E               E
# 9             A               A
# 10            S               S
# 11            S               S
# 12            D               D
# 13            S               S
# 14            A               A
# 15            S               S
# 16            C               C
# 17            S               S
# 18            S               S
# 19            S               S

# %% [markdown]
# # Comparing Total Actual marks, Predicted Marks, Actual Grade and Predicted Grade Together

# %%
df5 = pd.DataFrame({'Actual_Total_Marks':total_actual_marks, 'Predicted_Total_Marks':total_predicted_marks,
                    'Actual_Grade':actual_grade, 'Predicted_Grade':predicted_grade})
df5.head(20)
# Out:
#     Actual_Total_Marks  Predicted_Total_Marks Actual_Grade Predicted_Grade
# 0                   43              49.281811            E               D
# 1                   60              64.847602            C               C
# 2                   24              20.841271            F               F
# 3                   51              50.173964            D               D
# 4                   43              47.680011            E               D
# 5                   53              51.649750            D               D
# 6                   65              66.171412            C               B
# 7                   30              35.853966            F               E
# 8                   38              35.949441            E               E
# 9                   85              80.162021            A               A
# 10                  90              87.175884            S               S
# 11                  89              88.068036            S               S
# 12                  51              49.998253            D               D
# 13                  92              88.068036            S               S
# 14                  77              75.914302            A               A
# 15                  95              95.264402            S               S
# 16                  61              64.973616            C               C
# 17                  97              94.372250            S               S
# 18                  90              89.852340            S               S
# 19                  88              88.068036            S               S

# %% [markdown]
# # Accuracy check of the Model

# %%
# Accuracy check
# usign R-squared (R²) score

from sklearn.metrics import r2_score

acc = 100*(r2_score(y_test, y_pred))
print("Accuracy of the model is : %.2f" %acc)
# Out:
# Accuracy of the model is : 94.78

# %% [markdown]
# # 2. Logistic Regression Model

# %% [markdown]
# # ...........................................................

# %% [markdown]
# # Assigning Independent variable X and Dependent variable y

# %%
# Let's separate Independent variable X and Dependent variable y

X= df[['Study_hour', 'Assignment', 'Attendance', 'Quiz_one', 'Quiz_two', 'Midsem', 'Endsem']]
y = df['Pass_Fail']

# %% [markdown]
# # Spliting Data Set

# %%
# split data for training and testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40)

# Calculate the sizes of each segment for the pie chart
sizes = [len(X_train), len(X_test), len(y_train), len(y_test)]

# Define the colors for each segment for the pie chart
colors = ['lightblue', 'lightgreen', 'cyan', 'green']

# Create the pie chart on the first subplot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.pie(sizes, labels=['X_train', 'X_test', 'y_train', 'y_test'], colors=colors, autopct='%1.1f%%', startangle=90)
ax1.set_title('Data Split')

# Calculate the sizes of each segment for the bar chart
train_size = len(X_train)
test_size = len(X_test)
sizes = [train_size, test_size]
labels = ['Training set', 'Testing set']
colors = ['red', 'teal']

# Create the bar chart on the second subplot
bars = ax2.bar(labels, sizes, color=colors)
ax2.set_title('Proportions of Training and Testing Sets')
ax2.set_xlabel('Dataset')
ax2.set_ylabel('Number of samples')

# Add text labels for each bar
for bar in bars:
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height, '%d' % int(height), ha='center', va='bottom')

# Adjust the layout
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# # Training The Model

# %%
# Training the model

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# # Prediction

# %%
# prediction by giving the X_test data to the model 
# and geting prediction data in y_pred variable

y_pred=model.predict(X_test)

# %% [markdown]
# # Comparing Actual Pass/Fail result with the Prediction result

# %%
df6 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df6.head(20)
# Out:
#      Actual Predicted
# 2653   pass      pass
# 971    pass      pass
# 1045   pass      pass
# 1454   fail      fail
# 3675   pass      pass
# 1926   fail      fail
# 430    pass      pass
# 1409   pass      pass
# 1605   fail      fail
# 3544   pass      pass
# 1763   pass      pass
# 2751   pass      pass
# 2572   pass      pass
# 825    pass      pass
# 2317   fail      fail
# 890    fail      fail
# 2928   pass      pass
# 697    fail      fail
# 1896   pass      pass
# 3307   pass      pass

# %% [markdown]
# # Accuracy Check of the Model

# %%
# checking Accuracy
acc=100*(accuracy_score(y_test, y_pred))
print("Accuracy of the model is : %.2f" %acc)
# Out:
# Accuracy of the model is : 98.75
